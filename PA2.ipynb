# %% [markdown]
# # Programming Assignment 2
# Miranda G. Bilodeau | Fall 2026

# %% [markdown]
# ## Task 1:
# Storing and Printing Personal Information with Variables

# %%
myname='Miranda G. Bilodeau'
myage='21'
myheight="5'6''"
favcolor='green'
print("Hi! My name is "+myname+", and I'm "+myage+". I'm about "+myheight+", and while my favorite color changes a lot, right now it's probably "+favcolor+"!")
# Out:
# Hi! My name is Miranda G. Bilodeau, and I'm 21. I'm about 5'6'', and while my favorite color changes a lot, right now it's probably green!

# %% [markdown]
# ## Task 2:
# Converting Distances with Variables

# %%
miles_distance=10
kilometers=miles_distance*1.60934

# %%
print("I have to drive about "+str(miles_distance)+" miles to get to Bellarmine. That's about "+str(kilometers)+" kilometers!")
# Out:
# I have to drive about 10 miles to get to Bellarmine. That's about 16.0934 kilometers!

# %% [markdown]
# ## Task 3:
# Working with Running Times (in Minutes)

# %%
run1=13
run2=11
#B1. 
print("B1. "+str(run1+run2))
#B2.
print("B2. "+str(run1-run2))
#B3. 
print("B3. "+str(run2*2))
#B4. 
print("B4. "+str((run1+run2)/2))
# Out:
# B1. 24
# B2. 2
# B3. 22
# B4. 12.0

# %% [markdown]
# ## Task 4:
# Manipulating Strings

# %%
# A.
quote="\t\"Rage, rage against the dying of the light.\""
print("A. "+quote+ " - Dylan Thomas")
# B.
print("B. "+str(len(quote)))
# C.
print("C. "+quote.upper())
print(quote.lower())
# D.
print("D. "+quote.strip())
# E. 
print("E. ")
print(quote.split(' '))
# Out:
# A. 	"Rage, rage against the dying of the light." - Dylan Thomas
# B. 45
# C. 	"RAGE, RAGE AGAINST THE DYING OF THE LIGHT."
# 	"rage, rage against the dying of the light."
# D. "Rage, rage against the dying of the light."
# E.
# ['\t"Rage,', 'rage', 'against', 'the', 'dying', 'of', 'the', 'light."']

# %% [markdown]
# ## Task 5:
# Managing User Input & Operations

# %%
#A. 
a=int(input("Enter the length of the first leg: "))
b=int(input("Enter the length of the second leg: "))
# B.
c=((a**2)+(b**2))**0.5
# C.
print("The hypotenuse of your triangle is "+str(round(c, 2))+" units.")
# Out:
# Enter the length of the first leg:  3
# Enter the length of the second leg:  7
# The hypotenuse of your triangle is 7.62 units.
