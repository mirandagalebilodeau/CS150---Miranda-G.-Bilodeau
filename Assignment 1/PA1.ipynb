# %% [markdown]
# # Miranda G. Bilodeau - Markdown Practice

# %% [markdown]
# ### Miranda here! I'm a junior majoring in biology in hopes of going into education or museum work, and outside of class I really enjoy writing and drawing! I've been interested in coding for a little while now - I got into writing HTML (and a tiny bit of CSS) on a site called toyhou.se, and I've been wanting to learn more ever since!

# %% [markdown]
# The activities we'll be doing in this course include...
# * Programming Assignments (5)
# * Quizzes (4)
# * Attendance / In-Class Participation (daily)
# * Exams (2)
# * Projects (2)

# %% [markdown]
# The modules we'll be covering in this course include...
# 1. Variables, Simple Data Types, and GitHub Discussion
# 2. Lists and Tuples
# 3. "If" Statements
# 4. Loops
# 5. Lists and Tuples, part 2
# 6. Dictionaries
# 7. Sets, Functions, and Libraries
# 8. Class Datatypes and Exceptions
# 9. NumPy Arrays
# 10. Pandas and Files Excerpt

# %% [markdown]
# We'll be working primarily with the coding language **Python**!

# %% [markdown]
# In order to do this, we'll need to *create and edit .jpynb files* using the program *JupyterNotebook*, which is accessed through the *Anaconda Navigator*.

# %% [markdown]
# Today, my car got a flat, and so I learned ``how to change a tire``!

# %% [markdown]
# My GitHub repository can be accessed through [this link](https://github.com/mirandagalebilodeau/CS150---Miranda-G.-Bilodeau)!

# %% [markdown]
# ![Bellarmine's coat of arms, a maroon shield split into four quadrants.](bellogo.png)

# %% [markdown]
# This practice really helped reinforce what we learned about the markdown formatting system in class, which I'm extremely thankful for! As I mentioned earlier, I know a tiny bit of HTML, and I've gotten lost in my own code enough to know how ridiculously important being able to break up and annotate your work is. And while we're on the subject of HTML, formatting headings really tripped me up when I was learning it. I'm glad, then, that I got a chance to practice implementing them in markdown. The same can be said for bulleted / numbered lists, bold / italic font, and links - while I was already kind of familiar with them thanks to Discord (a messaging service that uses markdown for formatting), it was nice to review them here. However, there were two elements I wasn't at *all* familiar with prior to this class - markdown images and backtick highlighting - and that made practicing them particularly fulfilling.
